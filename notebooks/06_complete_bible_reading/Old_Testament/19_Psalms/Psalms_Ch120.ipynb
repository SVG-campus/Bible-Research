# %% [markdown]
# # Psalms Chapter 120
# ## 🧠 Memorization & Retention Guide
#
# **Objective:** Read, summarize, and internalize the key wisdom of this chapter.

# %%
import pandas as pd
# In the future, this cell will load the specific text for this chapter
print("📖 OPENING PSALMS CHAPTER 120...")

# %% [markdown]
# ## 📝 1. Executive Summary
# *Write a 1-2 sentence summary of what happens in this chapter.*

# %% [markdown]
# ## 🔑 2. Key Verses
# *List the 2-3 most important verses to memorize.*

# %% [markdown]
# ## 💭 3. Reflection & Application
# *How does this apply to my life today?*

# %% [markdown]
# ### 📜 Chapter Text
#
# **1** [A Song of degrees.] In my distress I cried unto the LORD, and he heard me.
#
# **2** Deliver my soul, O LORD, from lying lips, {and} from a deceitful tongue.
#
# **3** What shall be given unto thee? or what shall be done unto thee, thou false tongue? {What shall be given...: or, What shall the deceitful tongue give unto thee? or, what shall it profit thee?} {done: Heb. added}
#
# **4** Sharp arrows of the mighty, with coals of juniper. {Sharp...: or, It is as the sharp arrows of the mighty man, with coals of juniper}
#
# **5** Woe is me, that I sojourn in Mesech, {that} I dwell in the tents of Kedar!
#
# **6** My soul hath long dwelt with him that hateth peace.
#
# **7** I {am for} peace: but when I speak, they {are} for war. {for peace: or, a man of peace}
